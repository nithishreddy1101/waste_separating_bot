# %%
from transformers import AutoModelForCausalLM, AutoProcessor
from PIL import Image
import torch

# %%
model_path = "/home/nithish/ROS/waste_ws/src/gemini_api/moondream2/snapshots/6b714b26eea5cbd9f31e4edb2541c170afa935ba"

processor = AutoProcessor.from_pretrained(
    model_path,
    trust_remote_code=True
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 model_path = "/home/nithish/ROS/waste_ws/src/gemini_api/moondream2/snapshots/6b714b26eea5cbd9f31e4edb2541c170afa935ba"
# ----> 3 processor = AutoProcessor.from_pretrained(
#       4     model_path,
#       5     trust_remote_code=True
#       6 )
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/models/auto/processing_auto.py:375, in AutoProcessor.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     373 try:
#     374     if not isinstance(config, PreTrainedConfig):
# --> 375         config = AutoConfig.from_pretrained(
#     376             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     377         )
#     379     processor_class = getattr(config, "processor_class", None)
#     380     if hasattr(config, "auto_map") and "AutoProcessor" in config.auto_map:
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:1443, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1438     trust_remote_code = resolve_trust_remote_code(
#    1439         trust_remote_code, pretrained_model_name_or_path, has_local_code, has_remote_code, upstream_repo
#    1440     )
#    1442 if has_remote_code and trust_remote_code:
# -> 1443     config_class = get_class_from_dynamic_module(
#    1444         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1445     )
#    1446     config_class.register_for_auto_class()
#    1447     return config_class.from_pretrained(pretrained_model_name_or_path, **kwargs)
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/dynamic_module_utils.py:583, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     571 # And lastly we get the class inside our newly created module
#     572 final_module = get_cached_module_file(
#     573     repo_id,
#     574     module_file + ".py",
#    (...)    581     repo_type=repo_type,
#     582 )
# --> 583 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/dynamic_module_utils.py:297, in get_class_in_module(class_name, module_path, force_reload)
#     294 module_spec = importlib.util.spec_from_file_location(name, location=module_file)
#     296 # Hash the module file and all its relative imports to check if we need to reload it
# --> 297 module_files: list[Path] = [module_file] + sorted(map(Path, get_relative_import_files(module_file)))
#     298 module_hash: str = hashlib.sha256(b"".join(bytes(f) + f.read_bytes() for f in module_files)).hexdigest()
#     300 module: ModuleType
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/dynamic_module_utils.py:164, in get_relative_import_files(module_file)
#     162 new_imports = []
#     163 for f in files_to_check:
# --> 164     new_imports.extend(get_relative_imports(f))
#     166 module_path = Path(module_file).parent
#     167 new_import_files = [f"{str(module_path / m)}.py" for m in new_imports]
#
# File ~/Documents/ML/mlenv/lib/python3.12/site-packages/transformers/dynamic_module_utils.py:133, in get_relative_imports(module_file)
#     123 def get_relative_imports(module_file: str | os.PathLike) -> list[str]:
#     124     """
#     125     Get the list of modules that are relatively imported in a module file.
#     126
#    (...)    131         `list[str]`: The list of relative imports in the module.
#     132     """
# --> 133     with open(module_file, encoding="utf-8") as f:
#     134         content = f.read()
#     136     # Imports of the form `import .xxx`
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nithish/.cache/huggingface/modules/transformers_modules/_6b714b26eea5cbd9f31e4edb2541c170afa935ba/layers.py'
